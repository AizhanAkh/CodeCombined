# %%
import numpy as np
# to get plots displayed in notebook
# %matplotlib notebook
import matplotlib.pyplot as plt
from math import pi

# %%
# Next, get all data points for models
# from output .dat files

# after "=" write path to the .dat file with Pk data (..._pk) or Cl data (..._cl)
# Output files (from .ini files above) I used are in PT-check/class/test_output/
# for example, lcdm_pk = "/Users/aizhan.akh/Documents/Projects/PT-check/class/test_output/lcdm_pk.dat"

lcdm_pk_l = "/u/aizhana/Projects/CodeCombined/output/dmeff/lcdm_linear_pk.dat"               # for LCDM
lcdm_cl_l = "/u/aizhana/Projects/CodeCombined/output/dmeff/lcdm_linear_cl_lensed.dat"
lcdm_pk_h = "/u/aizhana/Projects/CodeCombined/output/dmeff/lcdm_halofit_pk_nl_halofit.dat"
lcdm_cl_h = "/u/aizhana/Projects/CodeCombined/output/dmeff/lcdm_halofit_cl_lensed.dat"
lcdm_pk_pt = "/u/aizhana/Projects/CodeCombined/output/dmeff/lcdm_eft_pk_nl_pt.dat"
lcdm_cl_pt = "/u/aizhana/Projects/CodeCombined/output/dmeff/lcdm_eft_cl_lensed.dat"


dmeff0_pk_l = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_linear_pk.dat"               # for IDM with n = 0
dmeff0_cl_l = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_linear_cl_lensed.dat"        # m = 1 GeV
dmeff0_pk_h = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_halofit_pk_nl_halofit.dat"   # sigma = 2.1e-26
dmeff0_cl_h = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_halofit_cl_lensed.dat" 
dmeff0_pk_pt = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_eft_pk_nl_pt.dat" 
dmeff0_cl_pt = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_eft_cl_lensed.dat" 

dmeff2_pk_l = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_2_linear_pk.dat"               # for IDM with n = 0
dmeff2_cl_l = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_2_linear_cl_lensed.dat" 
dmeff2_pk_h = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_2_halofit_pk_nl_halofit.dat" 
dmeff2_cl_h = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_2_halofit_cl_lensed.dat" 
dmeff2_pk_pt = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_2_eft_pk_nl_pt.dat" 
dmeff2_cl_pt = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_2_eft_cl_lensed.dat" 

dmeff_2_pk_l = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_-2_linear_pk.dat"               # for IDM with n = 0
dmeff_2_cl_l = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_-2_linear_cl_lensed.dat" 
dmeff_2_pk_h = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_-2_halofit_pk_nl_halofit.dat" 
dmeff_2_cl_h = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_-2_halofit_cl_lensed.dat" 
dmeff_2_pk_pt = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_-2_eft_pk_nl_pt.dat" 
dmeff_2_cl_pt = "/u/aizhana/Projects/CodeCombined/output/dmeff/dmeff_-2_eft_cl_lensed.dat" 


lcdm_pk_b = "/u/aizhana/Projects/CodeCombined/output/dmeff/lcdm_more_b_pk.dat"               # for LCDM
lcdm_cl_b = "/u/aizhana/Projects/CodeCombined/output/dmeff/lcdm_more_b_cl_lensed.dat" 


dmeff_pk_b = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_max_halofit_pk.dat"               # for IDM with large sigma
dmeff_cl_b = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_max_halofit_cl_lensed.dat" 
dmeff_pk_l = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_max_linear_pk.dat"               # for IDM with large sigma
dmeff_cl_l = "/u/aizhana/Projects/CodeCombined/output/dmeff_n0/dmeff_n0_max_linear_cl_lensed.dat"
# NOTE to self: CLASS outputs ClPP as ClPP*l*(l+1)!

# check LCDM with more Baryons model linear
Pk_lcdm_b = np.genfromtxt(lcdm_pk_b)[:,1]
kk_lcdm_b = np.genfromtxt(lcdm_pk_b)[:,0]
ll_lcdm_b = np.genfromtxt(lcdm_cl_b)[:,0]
clTT_lcdm_b = np.genfromtxt(lcdm_cl_b)[:,1]
clPP_lcdm_b = np.genfromtxt(lcdm_cl_b)[:,5]
# check Dmeff model with large sigma HALOFIT
Pk_dmeff_0_b = np.genfromtxt(dmeff_pk_b)[:,1]
kk_dmeff_0_b = np.genfromtxt(dmeff_pk_b)[:,0]
ll_dmeff_0_b = np.genfromtxt(dmeff_cl_b)[:,0]
clTT_dmeff_0_b = np.genfromtxt(dmeff_cl_b)[:,1]
clPP_dmeff_0_b = np.genfromtxt(dmeff_cl_b)[:,5]
# check Dmeff model with large sigma LINEAR
Pk_dmeff_0_bl = np.genfromtxt(dmeff_pk_l)[:,1]
kk_dmeff_0_bl = np.genfromtxt(dmeff_pk_l)[:,0]
ll_dmeff_0_bl = np.genfromtxt(dmeff_cl_l)[:,0]
clTT_dmeff_0_bl = np.genfromtxt(dmeff_cl_l)[:,1]
clPP_dmeff_0_bl = np.genfromtxt(dmeff_cl_l)[:,5]

# check LCDM model linear
Pk_lcdm_l = np.genfromtxt(lcdm_pk_l)[:,1]
kk_lcdm_l = np.genfromtxt(lcdm_pk_l)[:,0]
ll_lcdm_l = np.genfromtxt(lcdm_cl_l)[:,0]
clTT_lcdm_l = np.genfromtxt(lcdm_cl_l)[:,1]
clPP_lcdm_l = np.genfromtxt(lcdm_cl_l)[:,5]
# check LCDM model HALOFIT
Pk_lcdm_h = np.genfromtxt(lcdm_pk_h)[:,1]
kk_lcdm_h = np.genfromtxt(lcdm_pk_h)[:,0]
ll_lcdm_h = np.genfromtxt(lcdm_cl_h)[:,0]
clTT_lcdm_h = np.genfromtxt(lcdm_cl_h)[:,1]
clPP_lcdm_h = np.genfromtxt(lcdm_cl_h)[:,5]
# check LCDM model PERTURBATION THEORY
Pk_lcdm_pt = np.genfromtxt(lcdm_pk_pt)[:,1]
kk_lcdm_pt = np.genfromtxt(lcdm_pk_pt)[:,0]
ll_lcdm_pt = np.genfromtxt(lcdm_cl_pt)[:,0]
clTT_lcdm_pt = np.genfromtxt(lcdm_cl_pt)[:,1]
clPP_lcdm_pt = np.genfromtxt(lcdm_cl_pt)[:,5]


# check Dmeff model w/ n= 0 LINEAR
Pk_dmeff_0_l = np.genfromtxt(dmeff0_pk_l)[:,1]
kk_dmeff_0_l = np.genfromtxt(dmeff0_pk_l)[:,0]
ll_dmeff_0_l = np.genfromtxt(dmeff0_cl_l)[:,0]
clTT_dmeff_0_l = np.genfromtxt(dmeff0_cl_l)[:,1]
clPP_dmeff_0_l = np.genfromtxt(dmeff0_cl_l)[:,5]
# check Dmeff model w/ n= 0 HALOFIT
Pk_dmeff_0_h = np.genfromtxt(dmeff0_pk_h)[:,1]
kk_dmeff_0_h = np.genfromtxt(dmeff0_pk_h)[:,0]
ll_dmeff_0_h = np.genfromtxt(dmeff0_cl_h)[:,0]
clTT_dmeff_0_h = np.genfromtxt(dmeff0_cl_h)[:,1]
clPP_dmeff_0_h = np.genfromtxt(dmeff0_cl_h)[:,5]
# check Dmeff model w/ n= 0 PERTURBATION THEORY
Pk_dmeff_0_pt = np.genfromtxt(dmeff0_pk_pt)[:,1]
kk_dmeff_0_pt = np.genfromtxt(dmeff0_pk_pt)[:,0]
ll_dmeff_0_pt = np.genfromtxt(dmeff0_cl_pt)[:,0]
clTT_dmeff_0_pt = np.genfromtxt(dmeff0_cl_pt)[:,1]
clPP_dmeff_0_pt = np.genfromtxt(dmeff0_cl_pt)[:,5]

# check Dmeff model w/ n= 2 LINEAR
Pk_dmeff_2_l = np.genfromtxt(dmeff2_pk_l)[:,1]
kk_dmeff_2_l = np.genfromtxt(dmeff2_pk_l)[:,0]
ll_dmeff_2_l = np.genfromtxt(dmeff2_cl_l)[:,0]
clTT_dmeff_2_l = np.genfromtxt(dmeff2_cl_l)[:,1]
clPP_dmeff_2_l = np.genfromtxt(dmeff2_cl_l)[:,5]
# check Dmeff model w/ n= 2 HALOFIT
Pk_dmeff_2_h = np.genfromtxt(dmeff2_pk_h)[:,1]
kk_dmeff_2_h = np.genfromtxt(dmeff2_pk_h)[:,0]
ll_dmeff_2_h = np.genfromtxt(dmeff2_cl_h)[:,0]
clTT_dmeff_2_h = np.genfromtxt(dmeff2_cl_h)[:,1]
clPP_dmeff_2_h = np.genfromtxt(dmeff2_cl_h)[:,5]
# check Dmeff model w/ n= 2 PERTURBATION THEORY
Pk_dmeff_2_pt = np.genfromtxt(dmeff2_pk_pt)[:,1]
kk_dmeff_2_pt = np.genfromtxt(dmeff2_pk_pt)[:,0]
ll_dmeff_2_pt = np.genfromtxt(dmeff2_cl_pt)[:,0]
clTT_dmeff_2_pt = np.genfromtxt(dmeff2_cl_pt)[:,1]
clPP_dmeff_2_pt = np.genfromtxt(dmeff2_cl_pt)[:,5]

# check Dmeff model w/ n= -2 LINEAR
Pk_dmeff__2_l = np.genfromtxt(dmeff_2_pk_l)[:,1]
kk_dmeff__2_l = np.genfromtxt(dmeff_2_pk_l)[:,0]
ll_dmeff__2_l = np.genfromtxt(dmeff_2_cl_l)[:,0]
clTT_dmeff__2_l = np.genfromtxt(dmeff_2_cl_l)[:,1]
clPP_dmeff__2_l = np.genfromtxt(dmeff_2_cl_l)[:,5]
# check Dmeff model w/ n= -2 HALOFIT
Pk_dmeff__2_h = np.genfromtxt(dmeff_2_pk_h)[:,1]
kk_dmeff__2_h = np.genfromtxt(dmeff_2_pk_h)[:,0]
ll_dmeff__2_h = np.genfromtxt(dmeff_2_cl_h)[:,0]
clTT_dmeff__2_h = np.genfromtxt(dmeff_2_cl_h)[:,1]
clPP_dmeff__2_h = np.genfromtxt(dmeff_2_cl_h)[:,5]
# check Dmeff model w/ n= -2 PERTURBATION THEORY
Pk_dmeff__2_pt = np.genfromtxt(dmeff_2_pk_pt)[:,1]
kk_dmeff__2_pt = np.genfromtxt(dmeff_2_pk_pt)[:,0]
ll_dmeff__2_pt = np.genfromtxt(dmeff_2_cl_pt)[:,0]
clTT_dmeff__2_pt = np.genfromtxt(dmeff_2_cl_pt)[:,1]
clPP_dmeff__2_pt = np.genfromtxt(dmeff_2_cl_pt)[:,5]

# %%
# Compare Matter Power Spectra and PT
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-5, 1); plt.ylim(1.e1, 1.e5) # up to the semi-linear scale
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
llabl = r'$'
plt.plot(kk_lcdm_l, Pk_lcdm_l, 'k-',label = "Planck 2015")

plt.plot(kk_lcdm_b,Pk_lcdm_b,'r-', label = r'$\Omega_{cdm}h^{2} = 0.2500$')

plt.legend(loc = "lower center")
plt.title("P(k) spectra of LCDM models \n (linear perturbations mode) ")
plt.show()
plt.savefig("Presentation_Pk_sensitivity.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xscale('linear');plt.yscale('log');#plt.xlim(0, 2500); #plt.ylim(1.e-2, 1.e5)
plt.xlabel(r'${\ell}$')
plt.ylabel(r'$C_{\ell} ^{\kappa\kappa}(l) $')
llabl = r'$'
plt.plot(ll_lcdm_l, ((ll_lcdm_l*(ll_lcdm_l+1))**1)*clPP_lcdm_l, 'k-',label = "Planck 2015")

plt.plot(ll_lcdm_b, ((ll_lcdm_b*(ll_lcdm_b+1))**1)*clPP_lcdm_b,'r-', label = r'$\Omega_{cdm}h^{2} = 0.2500$')

plt.legend(loc = "lower center")
plt.title("Comparison of " + r'$C_{\ell} ^{\kappa\kappa}$'+ " spectra of LCDM \n ")
plt.show()
#plt.savefig("Presentation_ClKappaKappa_sensitivity.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-5, 1); plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')

plt.plot(kk_lcdm_h,Pk_lcdm_h,'b-', label = "LCDM")
plt.plot(kk_dmeff_0_b,Pk_dmeff_0_b,'r--', label = 'Interacting DM')

plt.legend(loc = "lower center")
plt.title("Comparison of P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=1.e-23 cm^2)\, models$')
plt.show()
#plt.savefig("Presentation_exagerrated_comparison_P(k)_LCDM_IDM.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-5, 1.e2); #plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')

plt.plot(kk_lcdm_h,Pk_lcdm_h,'b-', label = "LCDM")
plt.plot(kk_dmeff_0_h,Pk_dmeff_0_h,'r--', label = 'Interacting DM')

plt.legend(loc = "lower center")
plt.title("Comparison of P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$' + " with HALOFIT")
plt.show()
#plt.savefig("Presentation_comparison_P(k)_LCDM_IDM_n=0.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all residual Pk spectra 
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
plt.figure()
plt.xscale('log');plt.yscale('linear');#plt.xlim(1.e-5, 1); #plt.ylim(1.e-2, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$(P(k)_{IDM} \, - P(k)_{LCDM})/\, P(k)_{LCDM}\,$')

plt.plot(kk_dmeff_0_l, (Pk_dmeff_0_l - Pk_lcdm_l)/Pk_lcdm_l, 'k--',label = "n = 0, Linear PT")

#plt.plot(kk_dmeff_0_pt,(Pk_dmeff_0_pt - Pk_lcdm_pt)/Pk_lcdm_pt,'r--', label = 'n = 0, Perturbation Theory')

plt.plot(kk_dmeff_0_h,(Pk_dmeff_0_h - Pk_lcdm_h)/Pk_lcdm_h,'b-.', label = 'n = 0, Halofit')

plt.legend(loc = "lower left")
plt.title("Residual P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
#plt.savefig("Presentation_comparison_Residual_HALOFIT_P(k)_LCDM_IDM_n=0.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all Pk spectra 
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-5, 1.e0); plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')

plt.plot(kk_lcdm_l, Pk_lcdm_l, 'k-',label = "LCDM, Linear")
#plt.plot(kk_dmeff_0_l, Pk_dmeff_0_l, 'k--',label = "n = 0, Linear")

plt.plot(kk_lcdm_h,Pk_lcdm_h,'b--', label = "LCDM, Halofit")
#plt.plot(kk_dmeff_0_h,Pk_dmeff_0_h,'b--', label = 'n = 0, Halofit')

plt.legend(loc = "lower center")
plt.title("Comparison of P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
plt.savefig("Presentation_comparison_PT_HALOFIT_Linear_P(k)_LCDM.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all Pk spectra 
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-5, 1.e0); plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')

plt.plot(kk_lcdm_l, Pk_lcdm_l, 'k--',label = "LCDM, Linear PT")
#plt.plot(kk_dmeff_0_l, Pk_dmeff_0_l, 'k--',label = "n = 0, Linear")

plt.plot(kk_lcdm_pt,Pk_lcdm_pt,'r-', label = "LCDM, Nonlinear PT {New Code}", linewidth = 3.)
#plt.plot(kk_dmeff_0_pt,Pk_dmeff_0_pt,'r--', label = 'n = 0, Perturbation Theory')

plt.plot(kk_lcdm_h,Pk_lcdm_h,'b--', label = "LCDM, Halofit")
#plt.plot(kk_dmeff_0_h,Pk_dmeff_0_h,'b--', label = 'n = 0, Halofit')

plt.legend(loc = "lower center")
plt.title("Comparison of P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
plt.savefig("Presentation_comparison_PT_HALOFIT_P(k)_LCDM.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all residual Pk spectra 
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
plt.figure()
plt.xscale('log');plt.yscale('linear');plt.xlim(1.e-5, 10); #plt.ylim(1.e-2, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$(P(k)_{IDM} \, - P(k)_{LCDM})/\, P(k)_{LCDM}\,$')

plt.plot(kk_dmeff_0_l, (Pk_dmeff_0_l - Pk_lcdm_l)/Pk_lcdm_l, 'k--',label = "IDM, Linear PT")

plt.plot(kk_dmeff_0_pt,(Pk_dmeff_0_pt - Pk_lcdm_pt)/Pk_lcdm_pt,'r-', label = 'IDM, Nonlinear PT {New Code}', linewidth = 3.0)

plt.plot(kk_dmeff_0_h,(Pk_dmeff_0_h - Pk_lcdm_h)/Pk_lcdm_h,'b-.', label = 'IDM, Halofit')

plt.legend(loc = "lower left")
plt.title("Residual P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
plt.savefig("Presentation_comparison_residual_PT_HALOFIT_P(k)_LCDM_IDM_n=0.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all Pk spectra 
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-5, 1.); plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_dmeff_0_l, Pk_dmeff_0_l, 'k--',label = "IDM, Linear PT")

plt.plot(kk_dmeff_0_pt,Pk_dmeff_0_pt,'r-', label = 'IDM, Nonlinear PT {New Code}', linewidth = 3.0)

plt.legend(loc = "lower center")
plt.title("Comparison of P(k) spectra of DM (n=0, m=1 GeV," +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
plt.savefig("Presentation_comparison_P(k)_IDM_n=0.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all Pk spectra 
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-1, 1.); plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_dmeff_0_l, Pk_dmeff_0_l, 'k-.',label = "n = 0, Linear")
plt.plot(kk_dmeff_0_l, Pk_lcdm_l, 'k-',label = "LCDM, Linear")
plt.plot(kk_dmeff_0_pt,Pk_dmeff_0_pt,'r-.', label = 'n = 0, Perturbation Theory')
plt.plot(kk_dmeff_0_pt,Pk_lcdm_pt,'r-', label = 'LCDM, Perturbation Theory')
plt.plot(kk_dmeff_0_h,Pk_dmeff_0_h,'b-.', label = 'n = 0, Halofit')
plt.plot(kk_dmeff_0_h,Pk_lcdm_h,'b-', label = 'LCDM, Halofit')
plt.legend(loc = "lower center")
plt.title("Comparison of P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
#plt.savefig("Presentation_comparison_maginified_LCDM_P(k)_IDM_n=0.pdf")

plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-2, 1.); plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_dmeff_0_l, Pk_dmeff_0_l, 'k-.',label = "n = 0, Linear")
#plt.plot(kk_dmeff_0_l, Pk_lcdm_l, 'k-',label = "LCDM, Linear")
plt.plot(kk_dmeff_0_pt,Pk_dmeff_0_pt,'r--', label = 'n = 0, Perturbation Theory')
#plt.plot(kk_dmeff_0_pt,Pk_lcdm_pt,'r-', label = 'LCDM, Perturbation Theory')
plt.plot(kk_dmeff_0_h,Pk_dmeff_0_h,'b-.', label = 'n = 0, Halofit')
#plt.plot(kk_dmeff_0_h,Pk_lcdm_h,'b-.', label = 'LCDM, Halofit')
plt.legend(loc = "lower center")
plt.title("Comparison of P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
#plt.savefig("Presentation_comparison_maginified_P(k)_IDM_n=0.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all Pk spectra 
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
plt.figure()
plt.xscale('log');plt.yscale('linear');plt.xlim(1.e-5, 10.); #plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_dmeff_0_l, Pk_dmeff_0_l-Pk_lcdm_l, 'k-',label = "n = 0, Linear")

plt.plot(kk_dmeff_0_pt,Pk_dmeff_0_pt-Pk_lcdm_pt,'r--', label = 'n = 0, Perturbation Theory')

plt.plot(kk_dmeff_0_h,Pk_dmeff_0_h-Pk_lcdm_h,'b-.', label = 'n = 0, Halofit')

plt.legend(loc = "upper left")
plt.title("Comparison of P(k) spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
#plt.savefig("Presentation_comparison_actual_difference_P(k)_IDM_n=0.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Compare HALOFIT and PT
# I think discrepancies are not that large and mainly come from the fact that the merged code is more precise
'''
plt.figure()
plt.xscale('log');plt.yscale('log');plt.xlim(1.e-5, 1); plt.ylim(1.e1, 1.e5)
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk_lcdm_l, Pk_lcdm_l, 'k-',label = "LCDM, Linear")

plt.plot(kk_lcdm_pt,Pk_lcdm_pt,'r-', label = "LCDM, Perturbation Theory")

plt.plot(kk_lcdm_h,Pk_lcdm_h,'b-', label = "LCDM, Halofit")

plt.legend(loc = "lower center")
plt.title("Comparison of P(k) spectra of LCDM \n ")
plt.show()

plt.figure()
plt.xscale('log');plt.yscale('log');#plt.xlim(1.e-5, 1); plt.ylim(1.e1, 1.e5)
plt.xlabel(r'${\ell}$')
plt.ylabel(r'${\ell}*({\ell}+1)*C_{\ell}^{TT}$')
plt.plot(ll_lcdm_l, clTT_lcdm_l, 'k-',label = "LCDM, Linear")
plt.plot(ll_lcdm_pt,clTT_lcdm_pt,'r-', label = "LCDM, Perturbation Theory")
plt.plot(ll_lcdm_h,clTT_lcdm_h,'b-', label = "LCDM, Halofit")
plt.legend(loc = "lower center")
plt.title("Comparison of ClTT(k) spectra of LCDM \n ")
plt.show()
'''
ell = np.array([42.0, 122.0, 202.0, 282.0, 362.0, 442.0, 522.0, 602.0, 682.0, 762.0 ,842.0 ,922.0 ,1002.0 ,1082.0 ,1162.0 ,1242.0 ,1322.0 ,1402.0 ,1482.0 ,1562.0 ,1642.0 ,1722.0 ,1802.0 ,1882.0 ,1962.0 ,2042.0 ,2122.0 ,2202.0 ,2282.0 ,2362.0 ,2442.0 ,2522.0 ,2602.0 ,2682.0 , 2762.0, 2842.0, 2922.0]) 
nlkk = np.array([1.02886566516913e-08,1.1194860550459957e-08,1.2505619136465732e-08,1.3639000292859354e-08,1.4726157985091727e-08,1.5725847204661933e-08,1.6938661270395064e-08,1.8682705809355073e-08,2.112299958392952e-08,2.3537204158565772e-08,2.6496287215049565e-08,3.025903245034381e-08,3.4250486637297883e-08,3.858609285601067e-08,4.3227517165236133e-08,4.881779318529917e-08,5.4637529106849264e-08,6.091794461679896e-08,6.748938330785925e-08,7.478835883220224e-08,8.228241718672807e-08,8.893682840859781e-08,9.60522674909952e-08,1.0384832218496256e-07,1.1192068433016309e-07,1.199852307972035e-07,1.3053890509577023e-07,1.43859054270254e-07,1.5863511614121002e-07,1.7420892487626716e-07,1.9100543065917838e-07,2.102343953615504e-07,2.2934157407025104e-07,2.4737779899712124e-07,2.6884587664392953e-07,2.918082225405003e-07,3.080468562881667e-07])
ellK = np.linspace(2, 2500, 2501)
nlK = np.interp(ellK, ell, nlkk)
    
noise_K = np.zeros(2499, 'float64')
for l in range(2, 2501):
    noise_K[l-2] = nlK[l-2]
    
plt.figure()
plt.xscale('linear');plt.yscale('log');plt.xlim(0, 2500); #plt.ylim(1.e-2, 1.e5)
plt.xlabel(r'${\ell}$')
plt.ylabel(r'$C_{\ell} ^{\kappa\kappa}(l) $')
#plt.plot(ll_lcdm_l, ((ll_lcdm_l*(ll_lcdm_l+1))**1)*clPP_lcdm_l, 'k-',label = "LCDM, Linear")
#plt.plot(ll_dmeff_0_l, ((ll_dmeff_0_l*(ll_dmeff_0_l+1))**1)*clPP_dmeff_0_l, 'k--',label = "n = 0, Linear")

plt.plot(ll_lcdm_pt, ((ll_lcdm_pt*(ll_lcdm_pt+1))**1)*clPP_lcdm_pt,'r-', label = "LCDM, Nonlinear PT {New Code}")
plt.plot(ll_dmeff_0_pt, ((ll_dmeff_0_pt*(ll_dmeff_0_pt+1))**1)*clPP_dmeff_0_pt,'r--', label = 'IDM, Nonlinear PT {New Code}', linewidth = 4.0)

plt.plot(ll_lcdm_h, ((ll_lcdm_h*(ll_lcdm_h+1))**1)*clPP_lcdm_h,'b-', label = "LCDM, Halofit")
plt.plot(ll_dmeff_0_h, ((ll_dmeff_0_h*(ll_dmeff_0_h+1))**1)*clPP_dmeff_0_h,'b--', label = 'IDM, Halofit')
#plt.plot(ll_dmeff_0_h, noise_K,'c-', label = 'CMB-S4 Nkk noise spectrum')
plt.legend(loc = "lower left")
plt.title("Comparison of " + r'$C_{\ell} ^{\kappa\kappa}$'+ " spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
plt.savefig("Presentation_comparison_Cl(kappa|kappa)_n=0.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.xscale('linear');plt.yscale('log');plt.xlim(0, 1000); plt.ylim(5.e-9, 4.e-7)
plt.xlabel(r'${\ell}$')
plt.ylabel(r'$C_{\ell} ^{\kappa\kappa}(l) $')
#plt.plot(ll_lcdm_l, ((ll_lcdm_l*(ll_lcdm_l+1))**1)*clPP_lcdm_l, 'k-',label = "LCDM, Linear")
#plt.plot(ll_dmeff_0_l, ((ll_dmeff_0_l*(ll_dmeff_0_l+1))**1)*clPP_dmeff_0_l, 'k--',label = "n = 0, Linear")

plt.plot(ll_lcdm_pt, ((ll_lcdm_pt*(ll_lcdm_pt+1))**1)*clPP_lcdm_pt,'r-', label = "LCDM, Perturbation Theory")
plt.plot(ll_dmeff_0_pt, ((ll_dmeff_0_pt*(ll_dmeff_0_pt+1))**1)*clPP_dmeff_0_pt,'r--', label = 'n = 0, Perturbation Theory')

plt.plot(ll_lcdm_h, ((ll_lcdm_h*(ll_lcdm_h+1))**1)*clPP_lcdm_h,'b-', label = "LCDM, Halofit")
plt.plot(ll_dmeff_0_h, ((ll_dmeff_0_h*(ll_dmeff_0_h+1))**1)*clPP_dmeff_0_h,'b--', label = 'n = 0, Halofit')
plt.plot(ll_dmeff_0_h, noise_K,'c-', label = 'CMB-S4 Nkk noise spectrum')
plt.legend(loc = "upper right")
plt.title("Comparison of " + r'$C_{\ell} ^{\kappa\kappa}$'+ " spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\, models$')
plt.show()
#plt.savefig("Presentation_comparison_Cl(kappa|kappa)_n=0.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all residual Cl/kappa/kappa spectra 
# I NEED TO PLOT THE ERROR BARS!!!
plt.figure()
plt.xscale('linear');plt.yscale('linear');plt.xlim(0, 2000); #plt.ylim(-3., 3.)
plt.xlabel(r'${\ell}$')
plt.ylabel(r'$ Residual \,\, in \,\, C_{\ell}^{\kappa\kappa} in \,\, \% $')

plt.plot(ll_dmeff_0_l, 100*(clPP_dmeff_0_l- clPP_lcdm_l)/clPP_lcdm_l, 'k--',label = "IDM, Linear PT")

plt.plot(ll_dmeff_0_pt, 100*(clPP_dmeff_0_pt - clPP_lcdm_pt)/clPP_lcdm_pt,'r--', label = 'IDM, Nonlinear PT {New Code}', linewidth = 2.50)

plt.plot(ll_dmeff_0_h, 100*(clPP_dmeff_0_h - clPP_lcdm_h)/clPP_lcdm_h,'b--', label = 'IDM, Halofit')
#plt.plot(ll_lcdm_pt, 100*np.sqrt(sigma_Cl_sq)/((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt), 'c-',linewidth=2.0, label = "error bars, CMB-S4")
#plt.plot(ll_lcdm_pt, -100*np.sqrt(sigma_Cl_sq)/((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt), 'c-',linewidth=2.0, label = "error bars, CMB-S4")

plt.legend(loc = "upper left")
plt.title("Residual " + r'$C_{\ell} ^{\kappa\kappa}$'+ " spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\,\ models$')
plt.show()
plt.savefig("Presentation_Residual_Cl(kappa|kappa)_n=0.pdf")

# plots all residual Cl/kappa/kappa spectra 
# I NEED TO PLOT THE ERROR BARS!!!
plt.figure()
plt.xscale('linear');plt.yscale('linear');plt.xlim(0,2000); plt.ylim(-3., 3.)
plt.xlabel(r'${\ell}$')
plt.ylabel(r'$ Residual \,\, in \,\, C_{\ell}^{\kappa\kappa} in \,\, \% $')

plt.plot(ll_dmeff_0_l, 100*(clPP_dmeff_0_l- clPP_lcdm_l)/clPP_lcdm_l, 'k--',label = "IDM, Linear PT")

plt.plot(ll_dmeff_0_pt, 100*(clPP_dmeff_0_pt - clPP_lcdm_pt)/clPP_lcdm_pt,'r--', label = 'IDM, Nonlinear PT {New Code}')

plt.plot(ll_dmeff_0_h, 100*(clPP_dmeff_0_h - clPP_lcdm_h)/clPP_lcdm_h,'b--', label = 'IDM, Halofit')

plt.plot(ll_lcdm_pt, 100*np.sqrt(sigma_Cl_sq)/((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt), 'c-',linewidth=2.0, label = "error bars, CMB-S4")
plt.plot(ll_lcdm_pt, -100*np.sqrt(sigma_Cl_sq)/((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt), 'c-',linewidth=2.0)

plt.legend(loc = "upper right")
plt.title("Residual " + r'$C_{\ell} ^{\kappa\kappa}$'+ " spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\,\ models$')
plt.show()
#plt.savefig("Presentation_Residual_Cl(kappa|kappa)_n=0 with errors.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# plots all residual Cl/kappa/kappa spectra 

plt.figure()
plt.xscale('linear');plt.yscale('linear');plt.xlim(0, 2500); plt.ylim(-3, 3)
plt.xlabel(r'${\ell}$')
plt.ylabel(r'$ Residual \,\, in \,\, C_{\ell}^{\kappa\kappa} in \,\, \% $')

plt.plot(ll_dmeff_0_pt, 100*(clPP_dmeff_0_pt - clPP_lcdm_pt)/clPP_lcdm_pt,'r--', label = 'n = 0, Nonlinear PT')
plt.plot(ll_dmeff_2_pt, 100*(clPP_dmeff_2_pt - clPP_lcdm_pt)/clPP_lcdm_pt,'b--', label = 'n = 2, Nonlinear PT')
plt.plot(ll_dmeff__2_pt, 100*(clPP_dmeff__2_pt - clPP_lcdm_pt)/clPP_lcdm_pt,'m--', label = 'n = -2, Nonlinear PT')

plt.plot(ll_lcdm_pt, 100*np.sqrt(sigma_Cl_sq)/((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt), 'c-',linewidth=2.0, label = "error bars, CMB-S4")
plt.plot(ll_lcdm_pt, -100*np.sqrt(sigma_Cl_sq)/((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt), 'c-',linewidth=2.0)

plt.legend(loc = "upper right")
plt.title("Residual " + r'$C_{\ell} ^{\kappa\kappa}$'+ " spectra of LCDM \n " + 'and IDM models')
plt.show()
plt.savefig("Presentation_Residual_Cl(kappa|kappa)_all_n.pdf")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ell = np.array([42.0, 122.0, 202.0, 282.0, 362.0, 442.0, 522.0, 602.0, 682.0, 762.0 ,842.0 ,922.0 ,1002.0 ,1082.0 ,1162.0 ,1242.0 ,1322.0 ,1402.0 ,1482.0 ,1562.0 ,1642.0 ,1722.0 ,1802.0 ,1882.0 ,1962.0 ,2042.0 ,2122.0 ,2202.0 ,2282.0 ,2362.0 ,2442.0 ,2522.0 ,2602.0 ,2682.0 , 2762.0, 2842.0, 2922.0]) 
nlkk = np.array([1.02886566516913e-08,1.1194860550459957e-08,1.2505619136465732e-08,1.3639000292859354e-08,1.4726157985091727e-08,1.5725847204661933e-08,1.6938661270395064e-08,1.8682705809355073e-08,2.112299958392952e-08,2.3537204158565772e-08,2.6496287215049565e-08,3.025903245034381e-08,3.4250486637297883e-08,3.858609285601067e-08,4.3227517165236133e-08,4.881779318529917e-08,5.4637529106849264e-08,6.091794461679896e-08,6.748938330785925e-08,7.478835883220224e-08,8.228241718672807e-08,8.893682840859781e-08,9.60522674909952e-08,1.0384832218496256e-07,1.1192068433016309e-07,1.199852307972035e-07,1.3053890509577023e-07,1.43859054270254e-07,1.5863511614121002e-07,1.7420892487626716e-07,1.9100543065917838e-07,2.102343953615504e-07,2.2934157407025104e-07,2.4737779899712124e-07,2.6884587664392953e-07,2.918082225405003e-07,3.080468562881667e-07])
ellK = np.linspace(2, 2500, 2501)
nlK = np.interp(ellK, ell, nlkk)
    
noise_K = np.zeros(2499, 'float64')
for l in range(2, 2501):
    noise_K[l-2] = nlK[l-2]

# %%
n_bin = 50
f_sky = 1.0
sigma_Cl_sq = (((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt)**2 + noise_K**2)*2/(2*ll_lcdm_pt+1)/n_bin/f_sky

# %%
errors = "/u/aizhana/Projects/CodeCombined/notebooks/ClK_errors.csv"

# %%
errors_l = []
errors_y = []
import csv
with open(errors) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        errors_l.append(float(row[0]))
        errors_y.append(float(row[1]))

errors_l = np.array(errors_l)
errors_y = np.array(errors_y)

# %%
plt.figure()
plt.xscale('linear');plt.yscale('linear');#plt.xlim(0, 2500); 
plt.xlabel(r'${\ell}$')
plt.ylabel(r'$(C_{\ell}^{\kappa\kappa}(IDM) - C_{\ell}^{\kappa\kappa}({\lambda}CDM))/C_{\ell}^{\kappa\kappa}({\lambda}CDM) $')
plt.ylim(-2,2)
plt.scatter(errors_l, errors_y)
plt.plot(ll_lcdm_pt, 100*np.sqrt(sigma_Cl_sq)/((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt), 'c-',linewidth=2.0, label = "error bars, CMB-S4")
plt.plot(ll_lcdm_pt, -100*np.sqrt(sigma_Cl_sq)/((ll_lcdm_pt+1)*ll_lcdm_pt*clPP_lcdm_pt), 'c-',linewidth=2.0)
plt.plot(ll_dmeff_0_l, 100*(clPP_dmeff_0_l- clPP_lcdm_l)/clPP_lcdm_l, 'k-',label = "n = 0, Linear")

plt.plot(ll_dmeff_0_pt, 100*(clPP_dmeff_0_pt - clPP_lcdm_pt)/clPP_lcdm_pt,'r--', label = 'n = 0, Perturbation Theory')


plt.title("Residual " + r'$C_{\ell} ^{\kappa\kappa}$'+ " spectra of LCDM \n " + 'and IDM (n=0, m=1 GeV, ' +r'${\sigma}=2.1e-26 cm^2)\,\ models$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
errorbars = "/u/aizhana/Projects/CodeCombined/notebooks/pk.csv"
points_x = []
points_y = []
eb_t = []
eb_b = []
eb_r = []
eb_l = []
x_eb = []
y_eb = []
import csv
with open(errorbars) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        x_eb.append(float(row[0]))
        y_eb.append(float(row[1]))

x_eb = np.array(x_eb)
y_eb = np.array(y_eb)

# %%
length = len(x_eb)
for i in range(0, length, 5):
    points_x.append(x_eb[i])
    points_y.append(y_eb[i])
    eb_t.append(y_eb[i+1])
    eb_b.append(y_eb[i+2])
    eb_r.append(x_eb[i+3])
    eb_l.append(x_eb[i+4])
yerr = np.array(eb_t) - np.array(eb_b)
xerr = np.array(eb_r) - np.array(eb_l)
points_x = np.array(points_x)
points_y = np.array(points_y)

# %%
yerr.shape
np.array(points_x).shape
# Out:
# (16,)

# %%
xx=points_x[8:]
yy=points_y[8:]
y_e = yerr[8:]
x_e = xerr[8:]
len(y_e)
# Out:
# 8

# %%
xxx = np.delete(xx, 7)
yyy = np.delete(yy, 7)
yy_e = np.delete(y_e,7)
xx_e = np.delete(x_e, 7)
len(yyy)
#2,5
#8,11,14,15
# Out:
# 7

# %%
xxx = np.delete(points_x, [2, 5, 8, 11, 14, 15])
yyy = np.delete(points_y, [2, 5, 8, 11, 14, 15])
yy_e = np.delete(yerr,[2, 5, 8, 11, 14, 15])
xx_e = np.delete(xerr, [2, 5, 8, 11, 14, 15])
len(yyy)
#2,5
#8,11,14,15
# Out:
# 10

# %%
plt.figure()
plt.xscale('log');plt.yscale('log'); plt.xlim(1.e-4, 3.e0); plt.ylim(1.e0, 1.e4)
plt.errorbar(xxx, yyy, yerr = yy_e, xerr = xx_e, fmt='o')
plt.plot(kk_dmeff_0_h,Pk_lcdm_h,'b-')
plt.plot(kk_dmeff_0_pt,Pk_lcdm_pt,'r-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
yerr
# Out:
# array([804.63855855, 300.58608983, 416.88104245,  97.7392059 ,
#        303.36813882,  38.39473768,  76.28339211,  87.04383654,
#        180.28809987,  56.29203237,  49.85771254,  15.1756643 ,
#         32.26680497,  26.92287929,  19.62048537,  25.81432858])

# %%
xerr
# Out:
# array([0.05262602, 0.05396269, 0.52842511, 0.33964915, 0.05074905,
#        0.60925457, 0.10545174, 0.08704031, 0.05767445, 0.10909248,
#        0.092957  , 1.45100253, 0.14316945, 0.19091954, 0.21697312,
#        0.18752266])
